# %%
# get_img = lambda path: preprocess_input(\
#                        np.expand_dims(\
#                        image.img_to_array(\
#                        image.load_img('image/' + path, target_size=(224, 224))), axis=0))

# %%
# img1 = get_img('girl.jpg')

# %% [markdown]
# ---

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from model import ModelEmb
from model import cosine_similarity
import numpy as np
from keras.preprocessing import image
from model import preprocess_input
from skimage import io, transform
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-59211bb73598> in <module>()
# ----> 1 from model import ModelEmb
#       2 from model import cosine_similarity
#       3 import numpy as np
#       4 from keras.preprocessing import image
#       5 from model import preprocess_input
#
# ~/PicsArt/backend/model.py in <module>()
# ----> 1 from keras.applications.mobilenet_v2 import MobileNetV2
#       2 from keras.preprocessing import image
#       3 from keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
#       4 import numpy as np
#       5 from sklearn.metrics.pairwise import cosine_similarity
#
# ModuleNotFoundError: No module named 'keras'

# %%
url = "https://scontent-arn2-1.cdninstagram.com/vp/a05b4281cbd81433c49e620fea1ecc94/5C9B1DF8/t51.2885-15/sh0.08/e35/s640x640/43556265_948345168689036_2367865772941770752_n.jpg"

# %%
img_ka = transform.resize(io.imread(url), (224, 224, 3))
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /usr/local/lib/python3.5/dist-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
mb.run(np.array([img_ka, img_ka]))
# Out:
# array([[ 2.8444743,  0.       , 17.59393  , ..., 10.301337 ,  0.       ,
#         15.663241 ]], dtype=float32)

# %%
img1 = get_img('nature.jpg')
img2 = get_img('nature_3.jpg')

cosine_similarity(mb.run(img1), mb.run(img2))
# Out:
# array([[0.43956757]], dtype=float32)

# %% [markdown]
# ### Content / Style metric

# %%
from keras.applications.mobilenet_v2 import MobileNetV2
from keras.preprocessing import image
from keras.applications.mobilenet_v2 import preprocess_input, decode_predictions
from keras.models import Model
import numpy as np

from sklearn.metrics.pairwise import cosine_similarity

# %%
base_model = MobileNetV2(alpha=1.0, weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_4[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# ...

# %%
model_conv6 = Model(inputs=base_model.input, outputs=base_model.get_layer('block_6_depthwise').output)

# %%
girl_image = get_img('girl.jpg')

# %%
block6_depthwise = model.predict(girl_image)
block6_depthwise.shape
# Out:
# (1, 14, 14, 192)

# %%
img1
# Out:
# array([[[[ 0.765625 ,  0.78125  ,  0.6796875],
#          [ 0.765625 ,  0.78125  ,  0.6953125],
#          [ 0.765625 ,  0.78125  ,  0.6953125],
#          ...,
#          [ 0.7734375,  0.78125  ,  0.71875  ],
#          [ 0.7734375,  0.78125  ,  0.71875  ],
#          [ 0.7734375,  0.78125  ,  0.71875  ]],
#
#         [[ 0.765625 ,  0.78125  ,  0.6796875],
#          [ 0.765625 ,  0.78125  ,  0.6953125],
#          [ 0.7734375,  0.7890625,  0.703125 ],
#          ...,
#          [ 0.78125  ,  0.7890625,  0.7265625],
#          [ 0.7734375,  0.78125  ,  0.71875  ],
#          [ 0.7734375,  0.78125  ,  0.71875  ]],
#
#         [[ 0.7578125,  0.7734375,  0.671875 ],
#          [ 0.75     ,  0.765625 ,  0.6796875],
#          [ 0.7734375,  0.7890625,  0.703125 ],
#          ...,
#          [ 0.765625 ,  0.7734375,  0.7109375],
#          [ 0.7890625,  0.796875 ,  0.734375 ],
#          [ 0.7734375,  0.78125  ,  0.71875  ]],
#
#         ...,
#
# ...

# %%
np.array([img1, img1]).shape
# Out:
# (2, 1, 224, 224, 3)

# %%
mb.run(np.vstack([img1, img1]))
# Out:
# array([[ 1.6994562, 46.234146 ,  3.2722292, ...,  2.2956457,  0.       ,
#          0.       ]], dtype=float32)

# %%
import tensorflow

# %%
tensorflow.__version__
# Out:
# '1.10.1'
